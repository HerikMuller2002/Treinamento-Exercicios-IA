# %%
import numpy as np
import pandas as pd
import seaborn as srn
import matplotlib.pyplot as plt

# %%
dados = pd.read_csv("credit_data.csv")
dados.shape
# Out:
# (2000, 5)

# %%
dados.head()
# Out:
#    clientid        income        age         loan  default
# 0         1  66155.925095  59.017015  8106.532131        0
# 1         2  34415.153966  48.117153  6564.745018        0
# 2         3  57317.170063  63.108049  8020.953296        0
# 3         4  42709.534201  45.751972  6103.642260        0
# 4         5  66952.688845  18.584336  8770.099235        1

# %%
dados.isnull().sum()
# Out:
# clientid    0
# income      0
# age         3
# loan        0
# default     0
# dtype: int64

# %%
grafico = plt.scatter(dados["age"],dados["income"])

# %%
agrupados = dados.groupby(['age']).size()
agrupados
# Out:
# age
# -52.423280    1
# -36.496976    1
# -28.218361    1
#  18.055189    1
#  18.055874    1
#              ..
#  63.885044    1
#  63.887141    1
#  63.924976    1
#  63.930735    1
#  63.971796    1
# Length: 1997, dtype: int64

# %%
agrupados = dados.groupby(['default']).size()
agrupados
# Out:
# default
# 0    1717
# 1     283
# dtype: int64

# %%
dados.loc[dados['age'] < 0,"age"] = 41

# %%
mediana = dados.age.median()
print(mediana)
# Out:
# 41.3171591130085

# %%
dados.age.fillna(mediana,inplace=True)

# %%
dados.isnull().sum()
# Out:
# clientid    0
# income      0
# age         0
# loan        0
# default     0
# dtype: int64

# %%
grafico = plt.scatter(dados["age"],dados["income"])
